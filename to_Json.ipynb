# %%
# import pandas as pd
# import json

# def normalize_content_manipulation(value):
#     if isinstance(value, bool):
#         return value
#     if isinstance(value, str):
#         value = value.strip().lower() 
#         if value == 'true': 
#             return True
#         elif value == 'false': 
#             return False
#     return None

# # Load the CSV file (assuming 'train.csv' is in the current working directory)
# train_df = pd.read_csv("/home/cc/train/labels_new_2.csv")

# # Initialize an empty list to store the result
# result = []

# # Iterate through each row in the DataFrame
# for _, row in train_df.iterrows():
#     content_manipulation = normalize_content_manipulation(row['content_manipulation'])
#     # Check if the image has been manipulated or synthesized
#     if content_manipulation is None:
#         continue
#     if content_manipulation:
#         response = f"This image has been manipulated or synthesized. {row['prompts']}"
#     if not content_manipulation:
#         response = f"This image has not been manipulated or synthesized. {row['prompts']}"

#     # Build the entry dictionary
#     entry = {
#         "query": "Is this image manipulated or synthesized?",
#         "response": response,
#         "image_path": f"/home/cc/train/images/{row['image_id']}.jpg"
#     }

#     # Append the entry to the result list
#     result.append(entry)

# # Convert the result list to a JSON string
# json_output = json.dumps(result, ensure_ascii=False, indent=4)

# # Output the result to a JSON file
# output_path = "/home/cc/train/train.json"
# with open(output_path, 'w') as f:
#     f.write(json_output)

# output_path

# %%
# # Load the CSV file (assuming 'train.csv' is in the current working directory)
# test_df = pd.read_csv("/home/cc/test/labels_new_2.csv")

# # Initialize an empty list to store the result
# result = []

# # Iterate through each row in the DataFrame
# for _, row in test_df.iterrows():
#     content_manipulation = normalize_content_manipulation(row['content_manipulation'])
#     # Check if the image has been manipulated or synthesized
#     if content_manipulation is None:
#         continue
#     if content_manipulation:
#         response = f"This image has been manipulated or synthesized. {row['prompts']}"
#     if not content_manipulation:
#         response = f"This image has not been manipulated or synthesized. {row['prompts']}"

#     # Build the entry dictionary
#     entry = {
#         "query": "Is this image manipulated or synthesized?",
#         "response": response,
#         "image_path": f"/home/cc/train/images/{row['image_id']}.jpg"
#     }

#     # Append the entry to the result list
#     result.append(entry)

# # Convert the result list to a JSON string
# json_output = json.dumps(result, ensure_ascii=False, indent=4)

# # Output the result to a JSON file
# output_path = "/home/cc/test/test.json"
# with open(output_path, 'w') as f:
#     f.write(json_output)

# output_path

# %%
import pandas as pd
import json

def normalize_content_manipulation(value):
    if isinstance(value, bool):
        return value
    if isinstance(value, str):
        value = value.strip().lower() 
        if value == 'true': 
            return True
        elif value == 'false': 
            return False
    return None

# %%
train_df = pd.read_csv("/home/cc/train/labels_new_3.csv")
test_df = pd.read_csv("/home/cc/test/labels_new_3.csv")

# Initialize an empty list to store the conversation data
conversations = []

# Iterate through each row in the DataFrame
for i in range(len(train_df)):
    content_manipulation = train_df.iloc[i]['content_manipulation']
    
    # Skip rows where 'content_manipulation' is None
    if content_manipulation is None:
        continue
    
    # Construct the user query and assistant response
    query = "Is this image manipulated or synthesized?"
    if content_manipulation:
        response = f"This image has been manipulated or synthesized. {train_df.iloc[i]['prompts']}"
    else:
        response = f"This image has not been manipulated or synthesized. {train_df.iloc[i]['prompts']}"

    image_path = f"/home/cc/train/images/{train_df.iloc[i]['image_id']}.jpg"
    
    # Create the conversation entry
    conversation = {
        "id": f"identity_{i+1}",
        "conversations": [
            {
                "from": "user",
                "value": f"{query} <|vision_start|>{image_path}<|vision_end|>"
            },
            {
                "from": "assistant",
                "value": response
            }
        ]
    }
    
    # Append the conversation to the list
    conversations.append(conversation)

# Convert the result list to a JSON string
json_output = json.dumps(conversations, ensure_ascii=False, indent=4)

# Output the result to a JSON file
output_path = "/home/cc/train/train.json"
with open(output_path, 'w') as f:
    f.write(json_output)

output_path
# Out:
# '/home/cc/train/train.json'

# %%
# Initialize an empty list to store the conversation data
conversations = []

# Iterate through each row in the DataFrame
for i in range(len(test_df)):
    content_manipulation = train_df.iloc[i]['content_manipulation']
    
    # Skip rows where 'content_manipulation' is None
    if content_manipulation is None:
        continue
    
    # Construct the user query and assistant response
    query = "Is this image manipulated or synthesized?"
    if content_manipulation:
        response = f"This image has been manipulated or synthesized. {train_df.iloc[i]['prompts']}"
    else:
        response = f"This image has not been manipulated or synthesized. {train_df.iloc[i]['prompts']}"

    image_path = f"/home/cc/train/images/{train_df.iloc[i]['image_id']}.jpg"
    
    # Create the conversation entry
    conversation = {
        "id": f"identity_{i+1}",
        "conversations": [
            {
                "from": "user",
                "value": f"{query} <|vision_start|>{image_path}<|vision_end|>"
            },
            {
                "from": "assistant",
                "value": response
            }
        ]
    }
    
    # Append the conversation to the list
    conversations.append(conversation)

# Convert the result list to a JSON string
json_output = json.dumps(conversations, ensure_ascii=False, indent=4)

# Output the result to a JSON file
output_path = "/home/cc/test/test.json"
with open(output_path, 'w') as f:
    f.write(json_output)

output_path
# Out:
# '/home/cc/test/test.json'
